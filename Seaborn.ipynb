# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import os
# %matplotlib inline

# %%
auto = pd.read_csv("Automobile_data.csv")

# %%
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
plt.plot(auto["fuel-type"],auto["make"])
plt.show()

# %%
plt.scatter(auto["fuel-type"],auto["make"])
plt.show()

# %%
brandVSfuel=auto.groupby(["make","fuel-type"]).size().unstack(fill_value=0)

# %%
brandVSfuel
# Out:
# fuel-type      diesel  gas
# make
# alfa-romero         0    3
# audi                0    7
# bmw                 0    8
# chevrolet           0    3
# dodge               0    9
# honda               0   13
# isuzu               0    4
# jaguar              0    3
# mazda               2   15
# mercedes-benz       4    4
# mercury             0    1
# mitsubishi          0   13
# nissan              1   17
# peugot              5    6
# plymouth            0    7
# porsche             0    5
# renault             0    2
# saab                0    6
# subaru              0   12
# toyota              3   29
# volkswagen          4    8
# volvo               1   10

# %%
brandVSfuel.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='make'>

# %%
brandVSfuel.plot(kind='bar',stacked=False)
# Out:
# <Axes: xlabel='make'>

# %%
brandVSdoor = auto.groupby(["make", "num-of-doors"]).size().unstack(fill_value=0)

# %%
brandVSdoor
# Out:
# num-of-doors   ?  four  two
# make
# alfa-romero    0     0    3
# audi           0     5    2
# bmw            0     5    3
# chevrolet      0     1    2
# dodge          1     4    4
# honda          0     5    8
# isuzu          0     2    2
# jaguar         0     2    1
# mazda          1     7    9
# mercedes-benz  0     5    3
# mercury        0     0    1
# mitsubishi     0     4    9
# nissan         0     9    9
# peugot         0    11    0
# plymouth       0     4    3
# porsche        0     0    5
# renault        0     1    1
# saab           0     3    3
# subaru         0     9    3
# toyota         0    18   14
# volkswagen     0     8    4
# volvo          0    11    0

# %%
brandVSdoor.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='make'>

# %%
brandVSprice=auto.groupby(["make", "price"]).size().unstack(fill_value=0)

# %%
brandVSprice
# Out:
# price          10198  10245  10295  10345  10595  10698  10795  10898  10945  \
# make
# alfa-romero        0      0      0      0      0      0      0      0      0
# audi               0      0      0      0      0      0      0      0      0
# bmw                0      0      0      0      0      0      0      0      0
# chevrolet          0      0      0      0      0      0      0      0      0
# dodge              0      0      0      0      0      0      0      0      0
# honda              0      0      1      1      0      0      0      0      0
# isuzu              0      0      0      0      0      0      0      0      0
# jaguar             0      0      0      0      0      0      0      0      0
# mazda              0      1      0      0      1      0      1      0      1
# mercedes-benz      0      0      0      0      0      0      0      0      0
# mercury            0      0      0      0      0      0      0      0      0
# ...

# %%
brandVSprice.plot(kind='bar',stacked=True)
plt.ylim(90000,200000)
# Out:
# (90000.0, 200000.0)

# %% [markdown]
# 0-10000 - budget
# 10001-20000 - Avegrae
# 20001-30000 - above avg
# 30000 above - luxury
# create a graph of BrandVScar category(according to Price)

# %%
def prr(price):
    if price <= 10000:
        return 'Budget'
    elif price <= 20000:
        return 'Average'
    elif price <= 30000:
        return 'Above Average'
    else:
        return 'Luxury'

# %%
auto["prices"] = auto["price"].apply(prr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 auto["prices"] = auto["price"].apply(prr)
#
# File C:\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File C:\Python312\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
# ...

# %%
brandVScategory = auto.groupby(["make", "prr"]).size().unstack(fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 brandVScategory = groupby(["make", "prr"]).size().unstack(fill_value=0)
#
# NameError: name 'groupby' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'auto' is your DataFrame and it has 'brand' and 'price' columns

# Step 1: Categorize the prices
def categorize_price(price):
    if price <= 10000:
        return 'Budget'
    elif price <= 20000:
        return 'Average'
    elif price <= 30000:
        return 'Above Average'
    else:
        return 'Luxury'

auto['price_category'] = auto['price'].apply(categorize_price)

# Step 2: Group by 'brand' and 'price_category' and get the size of each group
brand_vs_category = auto.groupby(['make', 'price_category']).size().unstack(fill_value=0)

# Step 3: Plotting the grouped data
brand_vs_category.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Car Categories per Brand')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.legend(title='Price Category')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 17
#      14     else:
#      15         return 'Luxury'
# ---> 17 auto['price_category'] = auto['price'].apply(categorize_price)
#      19 # Step 2: Group by 'brand' and 'price_category' and get the size of each group
#      20 brand_vs_category = auto.groupby(['make', 'price_category']).size().unstack(fill_value=0)
#
# File C:\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
# ...

# %%
auto['price'] = pd.to_numeric(auto['price'], errors='coerce')

# Step 2: Drop rows with NaN values in 'price' column
auto = auto.dropna(subset=['price'])

# %%
def categorize_price(price):
    if price <= 10000:
        return 'Budget'
    elif price <= 20000:
        return 'Average'
    elif price <= 30000:
        return 'Above Average'
    else:
        return 'Luxury'

# %%
# Out:
# C:\Users\msi1\AppData\Local\Temp\ipykernel_10788\516762184.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   auto['price_category'] = auto['price'].apply(categorize_price)

# %%
def pri(price):
    if price <= 10000:
        return 'Budget'
    elif price <= 20000:
        return 'Average'
    elif price <= 30000:
        return 'Above Average'
    else:
        return 'Luxury'

brandVScategory = auto.groupby(['make', 'category']).size().unstack(fill_value=0)

brandVScategory.plot(kind='bar', stacked=True, figsize=(12, 8))
# Out:
# <Axes: xlabel='make'>

# %%
auto.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'price_category', 'category'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))

sns.lineplot(data=auto["wheel-base"],linewidth=1.5,label="wheelbase")
sns.lineplot(data=auto["engine-size"],linewidth=1.5,label="Engine size")
plt.title("Wheel Base vs Engine Size")
plt.ylabel("wheelbase")
plt.xlabel("Engine Size")
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.lineplot(data=auto["wheel-base"],linewidth=1.5,label="wheelbase")
sns.lineplot(data=auto["engine-size"],linewidth=1.5,label="enginebase")
plt.title("wheel base vs engine size")
plt.xlabel("wheelbase")
plt.ylabel("enginebase")
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.set(rc={"axes.facecolor":"#FFFFFF","axes.grid":False,"xtick.labelsize":10,"ytick.labelsize":10})
plt.title("wheel base vs engine size")
plt.xlabel("wheelbase")
plt.ylabel("enginebase")
sns.lineplot(x=auto["engine-size"],y=auto["wheel-base"].index.value,color='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 6
#       4 plt.xlabel("wheelbase")
#       5 plt.ylabel("enginebase")
# ----> 6 sns.lineplot(x=auto["engine-size"],y=auto["wheel-base"].index.value,color='r')
#       7 plt.show()
#
# AttributeError: 'Index' object has no attribute 'value'

# %%
plt.figure(figsize=(20,8))
sns.set(rc={"axes.facecolor":"#FFFFFF", "axes.grid":False, "xtick.labelsize":10, "ytick.labelsize":10})
plt.title("Wheel Base vs Engine Size")
plt.xlabel("Engine Size")
plt.ylabel("Wheel Base")
sns.lineplot(x=auto["engine-size"], y=auto["wheel-base"], color='r')
plt.show()

# %%
auto = pd.read_csv("titanic.csv")

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="pclass", y="survived", hue="sex", data=auto)
plt.title("Survival Rate by Class and Sex")
plt.xlabel("Passengerclass")
plt.ylabel("sriva; rate")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="embark_town", y="survived", data=auto)
plt.title("Survival Rate by Embarkation Town")
plt.xlabel("Embarkation Town")
plt.ylabel("Survival Rate")
plt.show()
