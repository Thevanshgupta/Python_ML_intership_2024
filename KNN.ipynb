# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
np.random.seed(50)
height=np.random.randint(140,200,200)
weight=np.random.randint(40,120,200)
bmi = weight/((height/100)**2)

BMI=pd.DataFrame({"Height":height,"Weight":weight,"BMI":bmi})
BMI
# Out:
#      Height  Weight        BMI
# 0       188     104  29.425079
# 1       172     118  39.886425
# 2       151      92  40.349107
# 3       185      66  19.284149
# 4       173      85  28.400548
# ..      ...     ...        ...
# 195     154      87  36.684095
# 196     196      99  25.770512
# 197     142      70  34.715334
# 198     180     103  31.790123
# 199     162      98  37.341869
#
# [200 rows x 3 columns]

# %%
def cateogary(bmi):
    bmi=float(bmi)
    if bmi<=19 and bmi>1:
        return "Under Weight"
    if bmi<=25 and bmi>19:
        return "Normal"
    else:
        return "Over Weight"

BMI['Cateogary']=BMI['BMI'].apply(cateogary)
BMI
# Out:
#      Height  Weight        BMI    Cateogary
# 0       188     104  29.425079  Over Weight
# 1       172     118  39.886425  Over Weight
# 2       151      92  40.349107  Over Weight
# 3       185      66  19.284149       Normal
# 4       173      85  28.400548  Over Weight
# ..      ...     ...        ...          ...
# 195     154      87  36.684095  Over Weight
# 196     196      99  25.770512  Over Weight
# 197     142      70  34.715334  Over Weight
# 198     180     103  31.790123  Over Weight
# 199     162      98  37.341869  Over Weight
#
# [200 rows x 4 columns]

# %%
X=BMI[["Height","Weight"]]
Y=BMI["Cateogary"]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=50)
print(X_train,X_test,Y_train,Y_test)
# Out:
#      Height  Weight
# 114     190      64
# 187     166      86
# 76      185     118
# 122     198      91
# 142     141      40
# ..      ...     ...
# 132     157      50
# 33      140     102
# 109     184      79
# 139     199      94
# 176     149      95
#
# [140 rows x 2 columns]      Height  Weight
# 112     178      67
# 165     162      48
# 12      145      59
# 73      198     116
# 144     148      40
# 20      175      67
# 199     162      98
# 8       177     118
# 39      170     112
# 88      172     103
# 81      141      90
# 197     142      70
# 69      147      43
# 160     170     109
# 25      146      91
# 99      193      54
# 151     196      54
# 23      166     117
# 138     167     114
# 159     151      67
# 89      159     119
# 82      149      83
# 24      166      61
# 174     197      56
# 137     167      65
# 83      169      72
# 107     180      45
# 34      199      52
# 97      176      94
# 167     177      83
# 123     192      77
# 157     190      90
# 75      140      61
# 152     155      44
# 117     168      49
# 149     143      44
# 63      191     102
# 54      140      85
# 125     196      77
# 80      159      94
# 170     192      90
# 183     195      49
# 38      155     104
# 153     171      81
# 40      181      82
# 190     141      61
# 177     199      75
# 131     182      88
# 13      142      88
# 121     145      58
# 1       172     118
# 116     196      50
# 100     154      97
# 166     186     119
# 168     193      44
# 48      143      76
# 178     140      91
# 108     170      40
# 61      166     107
# 16      147      68 114    Under Weight
# 187     Over Weight
# 76      Over Weight
# 122          Normal
# 142          Normal
#            ...
# 132          Normal
# 33      Over Weight
# 109          Normal
# 139          Normal
# 176     Over Weight
# Name: Cateogary, Length: 140, dtype: object 112          Normal
# 165    Under Weight
# 12      Over Weight
# 73      Over Weight
# 144    Under Weight
# 20           Normal
# 199     Over Weight
# 8       Over Weight
# 39      Over Weight
# 88      Over Weight
# 81      Over Weight
# 197     Over Weight
# 69           Normal
# 160     Over Weight
# 25      Over Weight
# 99     Under Weight
# 151    Under Weight
# 23      Over Weight
# 138     Over Weight
# 159     Over Weight
# 89      Over Weight
# 82      Over Weight
# 24           Normal
# 174    Under Weight
# 137          Normal
# 83      Over Weight
# 107    Under Weight
# 34     Under Weight
# 97      Over Weight
# 167     Over Weight
# 123          Normal
# 157          Normal
# 75      Over Weight
# 152    Under Weight
# 117    Under Weight
# 149          Normal
# 63      Over Weight
# 54      Over Weight
# 125          Normal
# 80      Over Weight
# 170          Normal
# 183    Under Weight
# 38      Over Weight
# 153     Over Weight
# 40      Over Weight
# 190     Over Weight
# 177    Under Weight
# 131     Over Weight
# 13      Over Weight
# 121     Over Weight
# 1       Over Weight
# 116    Under Weight
# 100     Over Weight
# 166     Over Weight
# 168    Under Weight
# 48      Over Weight
# 178     Over Weight
# 108    Under Weight
# 61      Over Weight
# 16      Over Weight
# Name: Cateogary, dtype: object

# %%
model=KNeighborsClassifier(n_neighbors=4)
model.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)
